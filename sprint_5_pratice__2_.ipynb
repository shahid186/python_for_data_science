# %%
import matplotlib.pyplot as pit
import pandas as pd
import numpy as np

# %%
data=pd.read_excel('DS1_C4_S5_Employee_Data_Practice.xlsx')
data
# Out:
#     Employee_Code   Gender Department  Annual Salary ($)  Age  Work_Experience
# 0             1010    Male        IT               27000   22                0
# 1             1011  Female        IT               48000   27                4
# 2             1012    Male      Sales              75000   31                7
# 3             1013    Male      Sales              61000   29                6
# 4             1014  Female    Finance              45000   27                4
# ..             ...     ...        ...                ...  ...              ...
# 65            1074  Female         HR              82500   43               13
# 66            1075    Male      Sales              53500   28                5
# 67            1076  Female         HR              57000   29                6
# 68            1077    Male      Sales              66500   33                7
# 69            1078    Male    Finance              92000   45               19
#
# [70 rows x 6 columns]

# %% [markdown]
# # task 1

# %%
h=data.groupby('Department')['Annual Salary ($)'].sum()

# %%
b=data.groupby('Department')['Annual Salary ($)'].sum()
b
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
data.columns
# Out:
# Index(['Employee_Code ', 'Gender', 'Department', 'Annual Salary ($)', 'Age',
#        'Work_Experience'],
#       dtype='object')

# %%
b=data.groupby('Department')['Annual Salary ($)'].mean()

# %%
m=data.groupby('Department')['Annual Salary ($)'].sum()

# %%
a=m.index

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(b,bins=3)
# Out:
# (array([1., 2., 1.]),
#  array([54450.        , 58233.33333333, 62016.66666667, 65800.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.bar(l,m)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 plt.bar(l,m)
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:2412, in bar(x, height, width, bottom, align, data, **kwargs)
#    2408 @_copy_docstring_and_deprecators(Axes.bar)
#    2409 def bar(
#    2410         x, height, width=0.8, bottom=None, *, align='center',
#    2411         data=None, **kwargs):
# -> 2412     return gca().bar(
#    2413         x, height, width=width, bottom=bottom, align=align,
#    2414         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# ...

# %%
b=m.values

# %%
n=b.index

# %%
plt.bar(n,b,color='black')
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(a,b,color='red')
# Out:
# <BarContainer object of 4 artists>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(a,b)
# Out:
# <BarContainer object of 4 artists>

# %%
b=h.index

# %%
a=h.values

# %%
pit.bar(b,a)
# Out:
# <BarContainer object of 4 artists>

# %%
#it department has higest no of annual salary 
t1=data.groupby('Department')['Annual Salary ($)'].sum()
t1
# Out:
# Department
# Finance     790000
# HR          987000
# IT         1282900
# Sales      1089000
# Name: Annual Salary ($), dtype: int64

# %%
a=t1.index

# %%
a
# Out:
# Index(['Finance', 'HR', 'IT ', 'Sales'], dtype='object', name='Department')

# %%
b=t1.values

# %%
b
# Out:
# array([ 790000,  987000, 1282900, 1089000], dtype=int64)

# %%
plt.bar(n,b,color='pink')
plt.xlabel('shahid is good boy')
plt.ylabel('shahid is bad boy')
plt.title('irtiza')
# Out:
# Text(0.5, 1.0, 'irtiza')

# %%
pit.bar(a,b)
pit.xlabel('department')
pit.ylabel('Annual Salary ($)')
pit.title('salary chart')
pit.show()

# %%
pit.bar(b,a,color='red')
pit.xlabel('shahid')
pit.ylabel('janu')
pit.title('nala')
pit .show()

# %% [markdown]
# # task 2

# %%
# total no of male and female employes in each departments
b=pd.crosstab(index=data['Department'],columns=data['Gender'])
g1=b.reset_index()
g1
# Out:
# Gender Department  Female  Male
# 0         Finance       2    11
# 1              HR      11     4
# 2             IT       10    12
# 3           Sales       4    16

# %%
x=pd.crosstab(index=data['Department'],columns=data['Gender'])
x.reset_index()
# Out:
# Gender Department  Female  Male
# 0         Finance       2    11
# 1              HR      11     4
# 2             IT       10    12
# 3           Sales       4    16

# %%
n=pd.crosstab(index=data['Department'],columns=data['Gender'])
n.reset_index()
# Out:
# Gender Department  Female  Male
# 0         Finance       2    11
# 1              HR      11     4
# 2             IT       10    12
# 3           Sales       4    16

# %%
m=pd.crosstab(index=data['Department'],columns=data['Gender'])
m.reset_index()
# Out:
# Gender Department  Female  Male
# 0         Finance       2    11
# 1              HR      11     4
# 2             IT       10    12
# 3           Sales       4    16

# %%
m.plot(x='Department',kind='bar',stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
m.plot(x='Department',kind='bar',stacked=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
m.plot(x='Department',kind='bar',stacked = True,figsize=(10,5),title ='department  wise  count');
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Department'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # task 3

# %%
#employees wit 0 years of experience in it andthere average salary
t3=data[(data['Department']== 'IT ') & (data['Work_Experience']==0)]
t3.reset_index()
# Out:
#    index  Employee_Code   Gender Department  Annual Salary ($)  Age  \
# 0      0            1010    Male        IT               27000   22
# 1      7            1017    Male        IT               28000   23
# 2     12            1022    Male        IT               29000   22
# 3     46            1055    Male        IT               27500   22
# 4     47            1056  Female        IT               29000   23
#
#    Work_Experience
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
g=data.groupby('Department')['Annual Salary ($)'].mean()
g
# Out:
# Department
# Finance    60769.230769
# HR         65800.000000
# IT         58313.636364
# Sales      54450.000000
# Name: Annual Salary ($), dtype: float64

# %%
b=data.groupby('Department')['Annual Salary ($)'].mean()
b
# Out:
# Department
# Finance    60769.230769
# HR         65800.000000
# IT         58313.636364
# Sales      54450.000000
# Name: Annual Salary ($), dtype: float64

# %%
pit.bar(g.index,g.values)
pit.xticks(rotation=45)
pit.xlabel('Department')
pit.ylabel('Annual Salary ($)')
pit.title('t3')
pit.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # task 4

# %%
#department wise ratio of the company by using pie chat
t4=data.groupby(['Department'])[['Annual Salary ($)']].sum()
t4
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
b=data.groupby('Department')['Annual Salary ($)'].sum()

# %%
b.plot(y='Annual Salary ($)',kind='pie',figsize=(17,9),autopct='%.2f%%',explode=(0,1,0,1))
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
b.plot(y='Annual Salary ($)',kind='pie',figsize=(15,7),autopct='%.2f%%',explode=(0,0,1,0))
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
b.plot(y='Annual Salary ($)',kind='pie',figsize=(15,7),autopct='%.2f%%',explode=(0,0,1,0))
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
e=b.index

# %%
v=b.index

# %%
plt.bar(v,b)
# Out:
# <BarContainer object of 4 artists>

# %%
v=b.values

# %%
plt.bar(e,v)
# Out:
# <BarContainer object of 4 artists>

# %%
b.plot(y='Annual Salary ($)',kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
t4.plot(y=['Annual Salary ($)'],kind='pie',autopct='%.2f%%')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t4.plot(y=['Annual Salary ($)'],kind='pie',autopct='%.2f%%')
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\plotting\_core.py:959, in PlotAccessor.__call__(self, *args, **kwargs)
#     957             # converted to series actually. copy to not modify
#     958             data = data[y].copy()
# --> 959             data.index.name = y
#     960 elif isinstance(data, ABCDataFrame):
#     961     data_cols = data.columns
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:1749, in Index.name(self, value)
#    1743 if self._no_setting_name:
#    1744     # Used in MultiIndex.levels to avoid silently ignoring name updates.
#    1745     raise RuntimeError(
#    1746         "Cannot set name on a level of a MultiIndex. Use "
# ...

# %%
d=data.groupby('Department')[['Annual Salary ($)']].sum()
d
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
d.plot(y='Annual Salary ($)',kind='pie',autopct='%.2f%%')
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
d=data.groupby('Annual Salary ($)')['Department']
d

# %%
h.plot(y='Annual Salary ($)',kind='pie',autopct='%.2f%%')

# %%
t4.plot(y='Annual Salary ($)',kind='pie',figsize=(15,7),autopct='%.2f%%')
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
t4.plot(y='Annual Salary ($)',kind='pie',figsi)

# %%
t4.plot(y='Annual Salary ($)',kind='pie',autopct='% .2f%%')
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
t4.plot(y='Annual Salary ($)',kind='pie',figsize=(7,7),autopct='% .2f%%')
# Out:
# <Axes: ylabel='Annual Salary ($)'>

# %%
plt.hist(data['Annual Salary ($)'],bins=5,edgecolor='red')
# Out:
# (array([34., 28.,  6.,  1.,  1.]),
#  array([ 27000.,  55600.,  84200., 112800., 141400., 170000.]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# # task 5

# %%
plt.hist(data['Annual Salary ($)'],bins=5,edgecolor='red')
# Out:
# (array([34., 28.,  6.,  1.,  1.]),
#  array([ 27000.,  55600.,  84200., 112800., 141400., 170000.]),
#  <BarContainer object of 5 artists>)

# %%
data.columns
# Out:
# Index(['Employee_Code ', 'Gender', 'Department', 'Annual Salary ($)', 'Age',
#        'Work_Experience'],
#       dtype='object')

# %%
plt.hist(data['Age'],edgecolor='red')
# Out:
# (array([11., 17., 13., 10.,  3.,  5.,  3.,  3.,  3.,  2.]),
#  array([22. , 24.8, 27.6, 30.4, 33.2, 36. , 38.8, 41.6, 44.4, 47.2, 50. ]),
#  <BarContainer object of 10 artists>)

# %%
m=data[(data['Annual Salary ($)'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 m=data[(data['Annual Salary ($)'])]
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
# ...

# %%
plt.scatter(x=data['Annual Salary ($)'],y=data['Department'])

# %%
plt.scatter(x=data['Annual Salary ($)'],y=data['Department'])

# %%
h=data.groupby('Annual Salary ($)')['Department']

# %%
l=h.index

# %%
m=h.values

# %%
plt.bar(l,m,edgecolor='red')
# Out:
# <BarContainer object of 47 artists>

# %%
h.plot(y='Annual Salary ($)',kind='pie',autopct='%.2f%%')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\groupby\groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\groupby\groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1601 """
#    1602 Apply function f in python space
#    1603
#    (...)
# ...

# %%
data.columns
# Out:
# Index(['Employee_Code ', 'Gender', 'Department', 'Annual Salary ($)', 'Age',
#        'Work_Experience'],
#       dtype='object')

# %%
plt.hist(data['Department'],bins=10,edgecolor='red')
# Out:
# (array([22.,  0.,  0., 20.,  0.,  0., 13.,  0.,  0., 15.]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
# 25 age group has higest no of employees
pit.hist(data['Age'],bins=5,edgecolor='black')
pit.xlabel('Age')
pit.ylabel('Frequency')
pit.show()

# %% [markdown]
# # task 6

# %%
plt.scatter(x=data['Work_Experience'],y=data['Annual Salary ($)'])

# %%
plt.scatter(x=data['Work_Experience'],y=data['Annual Salary ($)'])

# %%
#trend line of salary of employees
pit.scatter(x=data['Work_Experience'],y=data['Annual Salary ($)'])
pit.xlabel('Work_Experience')
pit.ylabel('salary')
# Out:
# Text(0, 0.5, 'salary')

# %% [markdown]
# # task 7

# %%
# sales department has less streach of boxplot
k=data.groupby(['Department'])[['Annual Salary ($)']].sum()
k
# Out:
#             Annual Salary ($)
# Department
# Finance                790000
# HR                     987000
# IT                    1282900
# Sales                 1089000

# %%
import seaborn as sb

# %%
sb.boxplot(data.Department,data['Annual Salary ($)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 sb.boxplot(data.Department,data['Annual Salary ($)'])
#
# TypeError: boxplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sb.boxplot(data.Department,data['Annual Salary ($)']);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sb.boxplot(data.Department,data['Annual Salary ($)'])
#
# TypeError: boxplot() takes from 0 to 1 positional arguments but 2 were given
