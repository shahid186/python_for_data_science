# %%
import matplotlib.pyplot as pit
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('DS1_C4_S5_Car_Data_Challenge.xlsx')

# %%
data=pd.read_excel('DS1_C4_S5_Car_Data_Challenge.xlsx')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1276 entries, 0 to 1275
# Columns: 139 entries, isker to Electric_Range
# dtypes: float64(15), int64(1), object(123)
# memory usage: 1.4+ MB

# %% [markdown]
# # task 1

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
f=data.groupby('Make')['Displacement'].mean()

# %%
c=data.groupby('Make')['Displacement'].mean()

# %%
data.groupby('Make')['Displacement'].agg(['mean','median'])
# Out:
#                          mean  median
# Make
# Aston Martin      5038.333333  5198.0
# Audi              2256.354839  1984.0
# Bajaj              216.000000   216.0
# Bentley           5447.833333  5974.0
# Bmw               2707.918919  2979.0
# Bugatti           7993.000000  7993.0
# Datsun            1065.066667  1198.0
# Dc                2000.000000  2000.0
# Ferrari           4589.500000  3902.0
# Fiat              1269.391304  1248.0
# Force             2447.000000  2596.0
# Ford              1551.325581  1498.0
# Honda             1444.875000  1498.0
# Hyundai           1350.558140  1197.0
# Icml              1994.000000  1994.0
# Isuzu             2578.800000  2499.0
# Jaguar            2679.545455  1999.0
# Jeep              2102.357143  1956.0
# Kia               1635.380952  1493.0
# Lamborghini       5409.692308  5204.0
# Land Rover        2795.000000  2993.0
# Land Rover Rover  3199.703704  2993.0
# Lexus             3491.600000  3456.0
# ...

# %%
b=data.groupby('Make')['Displacement'].agg(['mean','median'])

# %%
v=data.groupby('Make')['City_Mileage_km_litre'].mean()
v
# Out:
# Make
# Aston Martin         6.700000
# Audi                12.081250
# Bajaj                     NaN
# Bentley              5.020000
# Bmw                 13.686875
# Bugatti                   NaN
# Datsun              20.946667
# Dc                   8.000000
# Ferrari              4.320000
# Fiat                16.090909
# Force               14.000000
# Ford                10.660000
# Honda               16.805714
# Hyundai             16.679853
# Icml                 8.600000
# Isuzu                9.900000
# Jaguar               8.920909
# Jeep                13.975000
# Kia                       NaN
# Lamborghini          5.500000
# Land Rover                NaN
# Land Rover Rover     9.158000
# Lexus               18.150000
# Mahindra            20.003763
# Maruti Suzuki       21.062826
# Maruti Suzuki R           NaN
# Maserati             4.900000
# Mg                        NaN
# Mini                11.300000
# Mitsubishi           6.791667
# Nissan              15.324375
# ...

# %%
b=data.groupby('Make')['City_Mileage_km_litre'].max()

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
d=data.groupby('Make')['City_Mileage_km_litre'].sum()

# %%
plt.scatter(data,d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 plt.scatter(data,d)
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2838         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# ...

# %%
plt.scatter(data,d)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.scatter(data,d,color='red')
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2838         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
# ...

# %%
plt.figure(figsize=(5.23),color='red')
plt.scatter(c,v)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.figure(figsize=(5.23),color='red')
#       2 plt.scatter(c,v)
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\_api\deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:813, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
# ...

# %%
plt.scatter(x=d['Variant'],y=d['City_Mileage_km_litre'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Variant'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
b=d.head(3)

# %%
plt.hist(data['Displacement'],bins=6,color='red')
# Out:
# (array([460., 632., 111.,  34.,  19.,   8.]),
#  array([  72.        , 1392.16666667, 2712.33333333, 4032.5       ,
#         5352.66666667, 6672.83333333, 7993.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.hist(data['Displacement'],bins=6)
plt.show()

# %%
plt.hist(data['Displacement'],bins=3)
# Out:
# (array([1092.,  145.,   27.]),
#  array([  72.        , 2712.33333333, 5352.66666667, 7993.        ]),
#  <BarContainer object of 3 artists>)

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
plt.hist(data['City_Mileage_km_litre'],bins=8)
# Out:
# (array([370., 346.,   0.,   0.,   0.,   2.,   0.,   3.]),
#  array([  2. ,  15.5,  29. ,  42.5,  56. ,  69.5,  83. ,  96.5, 110. ]),
#  <BarContainer object of 8 artists>)

# %%
plt.hist(data['City_Mileage_km_litre'],bins=3)
# Out:
# (array([716.,   0.,   5.]),
#  array([  2.,  38.,  74., 110.]),
#  <BarContainer object of 3 artists>)

# %%
data.plot(y='City_Mileage_km_litre',kind='pie',figsize=(15,7),autopct='%.2f%%')
# Out:
# <Axes: ylabel='City_Mileage_km_litre'>

# %%
data.plot(y='City_Mileage_km_litre',kind='pie',figsize=(15,8),autopct='%.2f%%',explode=(0,0.9,0))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 data.plot(y='City_Mileage_km_litre',kind='pie',figsize=(15,8),autopct='%.2f%%',explode=(0,0.9,0))
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\plotting\_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
b.plot(y='City_Mileage_km_litre',kind='pie',figsize=(15,6),autopct='%.2f%%',explode=(0,0.9,0))
# Out:
# <Axes: ylabel='City_Mileage_km_litre'>

# %%
n=d.index

# %%
m=d.values

# %%
import matplotlib.pyplot as plt

# %%
plt.barh(n,m,color='red')
# Out:
# <BarContainer object of 39 artists>

# %%
data.groupby('Make')['City_Mileage_km_litre'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data.groupby('Make')['City_Mileage_km_litre'].max()
#
# NameError: name 'data' is not defined

# %%
data.groupby('Make')['City_Mileage_km_litre'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.groupby('Make')['City_Mileage_km_litre'].max()
#
# NameError: name 'data' is not defined

# %%
d=data.groupby('Make')['City_Mileage_km_litre'].max()

# %%
s=data.groupby('Make')['City_Mileage_km_litre'].max()
s.sort_values()
# Out:
# Make
# Maserati              5.20
# Ferrari               6.00
# Dc                    8.00
# Mitsubishi            8.25
# Icml                  8.60
# Aston Martin          9.10
# Bentley               9.60
# Lamborghini          10.60
# Porsche              11.60
# Mini                 12.30
# Isuzu                13.80
# Force                14.00
# Land Rover Rover     15.68
# Volvo                16.80
# Ford                 17.00
# Jeep                 17.50
# Skoda                18.00
# Bmw                  18.00
# Lexus                18.80
# Volkswagen           19.00
# Audi                 19.20
# Nissan               19.50
# Premier              20.00
# Toyota               20.32
# Fiat                 21.20
# Jaguar               21.27
# Datsun               21.38
# Hyundai              24.00
# Tata                 24.12
# Renault              25.17
# Honda                25.50
# Maruti Suzuki        28.40
# Mahindra            110.00
# Bajaj                  NaN
# ...

# %%
d=data.groupby('Make')['City_Mileage_km_litre'].max()

# %%
b=data.groupby('Make')['City_Mileage_km_litre'].agg(['mean','median'])

# %%
b.rename(columns={'mean':'average'},inplace=True)
b
# Out:
#                     average  median
# Make
# Aston Martin       6.700000   6.000
# Audi              12.081250  12.000
# Bajaj                   NaN     NaN
# Bentley            5.020000   5.300
# Bmw               13.686875  14.255
# Bugatti                 NaN     NaN
# Datsun            20.946667  20.600
# Dc                 8.000000   8.000
# Ferrari            4.320000   3.200
# Fiat              16.090909  17.000
# Force             14.000000  14.000
# Ford              10.660000   9.300
# Honda             16.805714  16.200
# Hyundai           16.679853  16.380
# Icml               8.600000   8.600
# Isuzu              9.900000   7.300
# Jaguar             8.920909   7.810
# Jeep              13.975000  12.800
# Kia                     NaN     NaN
# Lamborghini        5.500000   5.600
# Land Rover              NaN     NaN
# Land Rover Rover   9.158000   8.100
# Lexus             18.150000  18.000
# Mahindra          20.003763  16.000
# Maruti Suzuki     21.062826  21.400
# ...

# %%
c=data.groupby('Make')['City_Mileage_km_litre'].max()

# %%
v=data.groupby('Make')['City_Mileage_km_litre'].agg(['mean'])
v.rename(columns={'shahid':'Make'},inplace=True)
v
# Out:
#                        mean
# Make
# Aston Martin       6.700000
# Audi              12.081250
# Bajaj                   NaN
# Bentley            5.020000
# Bmw               13.686875
# Bugatti                 NaN
# Datsun            20.946667
# Dc                 8.000000
# Ferrari            4.320000
# Fiat              16.090909
# Force             14.000000
# Ford              10.660000
# Honda             16.805714
# Hyundai           16.679853
# Icml               8.600000
# Isuzu              9.900000
# Jaguar             8.920909
# Jeep              13.975000
# Kia                     NaN
# Lamborghini        5.500000
# Land Rover              NaN
# Land Rover Rover   9.158000
# Lexus             18.150000
# Mahindra          20.003763
# Maruti Suzuki     21.062826
# Maruti Suzuki R         NaN
# Maserati           4.900000
# Mg                      NaN
# Mini              11.300000
# Mitsubishi         6.791667
# Nissan            15.324375
# Porsche            8.400000
# ...

# %%
plt.hist(c,bins=4)
# Out:
# (array([32.,  0.,  0.,  1.]),
#  array([  5.2,  31.4,  57.6,  83.8, 110. ]),
#  <BarContainer object of 4 artists>)

# %%
c=data.groupby('Make')['City_Mileage_km_litre'].max()
c.sort_values(ascending=True)
# Out:
# Make
# Maserati              5.20
# Ferrari               6.00
# Dc                    8.00
# Mitsubishi            8.25
# Icml                  8.60
# Aston Martin          9.10
# Bentley               9.60
# Lamborghini          10.60
# Porsche              11.60
# Mini                 12.30
# Isuzu                13.80
# Force                14.00
# Land Rover Rover     15.68
# Volvo                16.80
# Ford                 17.00
# Jeep                 17.50
# Skoda                18.00
# Bmw                  18.00
# Lexus                18.80
# Volkswagen           19.00
# Audi                 19.20
# Nissan               19.50
# Premier              20.00
# Toyota               20.32
# Fiat                 21.20
# Jaguar               21.27
# Datsun               21.38
# Hyundai              24.00
# Tata                 24.12
# Renault              25.17
# Honda                25.50
# Maruti Suzuki        28.40
# Mahindra            110.00
# Bajaj                  NaN
# ...

# %%
data
# Out:
#       isker        Make      Model        Variant  Displacement  Cylinders  \
# 0         0        Tata  Nano Genx             Xt         624.0        2.0
# 1         1        Tata  Nano Genx             Xe         624.0        2.0
# 2         2        Tata  Nano Genx        Emax Xm         624.0        2.0
# 3         3        Tata  Nano Genx            Xta         624.0        2.0
# 4         4        Tata  Nano Genx             Xm         624.0        2.0
# ...     ...         ...        ...            ...           ...        ...
# 1271   1271       Honda       City   Vx Mt Diesel        1498.0        4.0
# 1272   1272       Honda       City   Zx Mt Diesel        1498.0        4.0
# 1273   1273       Honda       City  Zx Cvt Petrol        1497.0        4.0
# 1274   1274       Honda       City   V Cvt Petrol        1497.0        4.0
# 1275   1275  Mitsubishi    Montero         3.2 At        3200.0        4.0
#
# ...

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
x=data[['Model','Variant','Cylinders']]
x
# Out:
#           Model        Variant  Cylinders
# 0     Nano Genx             Xt        2.0
# 1     Nano Genx             Xe        2.0
# 2     Nano Genx        Emax Xm        2.0
# 3     Nano Genx            Xta        2.0
# 4     Nano Genx             Xm        2.0
# ...         ...            ...        ...
# 1271       City   Vx Mt Diesel        4.0
# 1272       City   Zx Mt Diesel        4.0
# 1273       City  Zx Cvt Petrol        4.0
# 1274       City   V Cvt Petrol        4.0
# 1275    Montero         3.2 At        4.0
#
# [1276 rows x 3 columns]

# %%
x=data[['Make','Model','Displacement']]
x.replace(to_replace='Tata',value='shahid')
# Out:
#             Make      Model  Displacement
# 0         shahid  Nano Genx         624.0
# 1         shahid  Nano Genx         624.0
# 2         shahid  Nano Genx         624.0
# 3         shahid  Nano Genx         624.0
# 4         shahid  Nano Genx         624.0
# ...          ...        ...           ...
# 1271       Honda       City        1498.0
# 1272       Honda       City        1498.0
# 1273       Honda       City        1497.0
# 1274       Honda       City        1497.0
# 1275  Mitsubishi    Montero        3200.0
#
# [1276 rows x 3 columns]

# %%
#fuel economy car and the name of manafacture top 10
t1=data.groupby('Make')['City_Mileage_km_litre'].max()
t1
# Out:
# Make
# Aston Martin          9.10
# Audi                 19.20
# Bajaj                  NaN
# Bentley               9.60
# Bmw                  18.00
# Bugatti                NaN
# Datsun               21.38
# Dc                    8.00
# Ferrari               6.00
# Fiat                 21.20
# Force                14.00
# Ford                 17.00
# Honda                25.50
# Hyundai              24.00
# Icml                  8.60
# Isuzu                13.80
# Jaguar               21.27
# Jeep                 17.50
# Kia                    NaN
# Lamborghini          10.60
# Land Rover             NaN
# Land Rover Rover     15.68
# Lexus                18.80
# Mahindra            110.00
# Maruti Suzuki        28.40
# Maruti Suzuki R        NaN
# Maserati              5.20
# Mg                     NaN
# Mini                 12.30
# Mitsubishi            8.25
# Nissan               19.50
# Porsche              11.60
# Premier              20.00
# Renault              25.17
# ...

# %%
a=c.sort_values(ascending=False).head(10).index
a
# Out:
# Index(['Mahindra', 'Maruti Suzuki', 'Honda', 'Renault', 'Tata', 'Hyundai',
#        'Datsun', 'Jaguar', 'Fiat', 'Toyota'],
#       dtype='object', name='Make')

# %%
a=c.sort_values(ascending=True).head(10).index

# %%
v=b.sort_values(ascending=True).head(10)
v
# Out:
# Make
# Maserati         5.20
# Ferrari          6.00
# Dc               8.00
# Mitsubishi       8.25
# Icml             8.60
# Aston Martin     9.10
# Bentley          9.60
# Lamborghini     10.60
# Porsche         11.60
# Mini            12.30
# Name: City_Mileage_km_litre, dtype: float64

# %%
b=c.sort_values(ascending=False).head(10)
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 b=c.sort_values(ascending=False).head(10)
#       2 b
#
# NameError: name 'c' is not defined

# %%
b=b.sort_values(ascending=False).head(10).index
b
# Out:
# Index(['Mahindra', 'Maruti Suzuki', 'Honda', 'Renault', 'Tata', 'Hyundai',
#        'Datsun', 'Jaguar', 'Fiat', 'Toyota'],
#       dtype='object', name='Make')

# %%
c=data.groupby('Make')['City_Mileage_km_litre'].max()
c.sort_values(ascending=True)

# %%
c.head(10)
# Out:
# Make
# Aston Martin     9.10
# Audi            19.20
# Bajaj             NaN
# Bentley          9.60
# Bmw             18.00
# Bugatti           NaN
# Datsun          21.38
# Dc               8.00
# Ferrari          6.00
# Fiat            21.20
# Name: City_Mileage_km_litre, dtype: float64

# %%
plt.barh(v,b)
# Out:
# <BarContainer object of 10 artists>

# %%
pit.barh(a,b,label='max millage',color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
pit.barh(a,b,label='Max mileage')
pit.title('Manufacture wisecity milage')
pit.xlabel('Manufacture')
pit.ylabel('max mileage')
pit.legend()
pit.show()

# %% [markdown]
# # task2

# %%
#fuel economy car and the name of manafacture in b/w 10 to 20
t2=t1.sort_values(ascending=False)[10:20].index
t2
# Out:
# Index(['Premier', 'Nissan', 'Audi', 'Volkswagen', 'Lexus', 'Skoda', 'Bmw',
#        'Jeep', 'Ford', 'Volvo'],
#       dtype='object', name='Make')

# %%
tr=c.sort_values(ascending=False)[10:20].index

# %%
pit.bar(tr,d,color='red')
# Out:
# <BarContainer object of 10 artists>

# %%
d=c.sort_values(ascending=False)[10:20]

# %%
pit.pie(t3,labels=c,autopct='2f%%')

# %%
c=t1.sort_values(ascending=False)[10:20]
c
# Out:
# Make
# Premier       20.0
# Nissan        19.5
# Audi          19.2
# Volkswagen    19.0
# Lexus         18.8
# Skoda         18.0
# Bmw           18.0
# Jeep          17.5
# Ford          17.0
# Volvo         16.8
# Name: City_Mileage_km_litre, dtype: float64

# %%
pit.barh(t2,c,label='Max mileage',color='r')
pit.title('Manufacture wisecity milage')
pit.xlabel('Manufacture')
pit.ylabel('max mileage')
pit.legend()
pit.show()

# %% [markdown]
# # task 3

# %%
#most preferable car and what is the % of passangers cars
t3=data['Body_Type'].value_counts().head(5)
t3
# Out:
# SUV          447
# Sedan        333
# Hatchback    316
# Coupe         41
# MUV           39
# Name: Body_Type, dtype: int64

# %%
data.columns
# Out:
# Index(['isker', 'Make', 'Model', 'Variant', 'Displacement', 'Cylinders',
#        'Valves_Per_Cylinder', 'Drivetrain', 'Cylinder_Configuration',
#        'Engine_Location',
#        ...
#        'Leather_Wrapped_Steering', 'Automatic_Headlamps', 'Engine_Type',
#        'ASR_/_Traction_Control', 'Cruise_Control', 'USB_Ports',
#        'Heads-Up_Display', 'Welcome_Lights', 'Battery', 'Electric_Range'],
#       dtype='object', length=139)

# %%
s=data['Model'].value_counts()
s
# Out:
# Nexon                              24
# Kuv100 Nxt                         22
# Compass                            21
# Xuv500                             21
# Amaze                              20
#                                    ..
# Lc 500H                             1
# Lx 450D                             1
# Mercedes-Benz S-Class Cabriolet     1
# R8                                  1
# Montero                             1
# Name: Model, Length: 263, dtype: int64

# %%
s=data['Body_Type'].value_counts().head()
s
# Out:
# SUV          447
# Sedan        333
# Hatchback    316
# Coupe         41
# MUV           39
# Name: Body_Type, dtype: int64

# %%
t3=data['Body_Type'].value_counts().head(5)
t3
# Out:
# SUV          447
# Sedan        333
# Hatchback    316
# Coupe         41
# MUV           39
# Name: Body_Type, dtype: int64

# %%
pit.pie(t3,labels=c,autopct='2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x2147dca8f40>,
# ...
#  [Text(0.40460912998259874, 1.0228838897620416, 'SUV'),
#   Text(-1.089806661655672, -0.14940361511998146, 'Sedan'),
#   Text(0.3242307715203902, -1.051130061790306, 'Hatchback'),
#   Text(1.044883587974835, -0.3438288637983082, 'Coupe'),
#   Text(1.0940353698476144, -0.11439671989350769, 'MUV')],
#  [Text(0.22069588908141746, 0.5579366671429318, '2f%'),
#   Text(-0.5944399972667301, -0.08149288097453533, '2f%'),
#   Text(0.17685314810203098, -0.5733436700674396, '2f%'),
#   Text(0.5699365025317281, -0.18754301661725897, '2f%'),
#   Text(0.596746565371426, -0.062398210851004186, '2f%')])

# %%
pit.pie(t3,labels=c,autopct='2f%%')
pit.show()

# %%
n=data['Body_Type'].value_counts().head()
c=n.index

# %%
c=t3.index

# %%
f=

# %%
pit.pie(t3,labels=c,autopct='2f%%')
pit.show()

# %%
pit.pie(t3,labels=c,autopct='2f%%')
pit.show()

# %%
l=t3.index
l
# Out:
# Index(['SUV', 'Sedan', 'Hatchback', 'Coupe', 'MUV'], dtype='object')

# %%
pit(pie(t3,labels=i,autopct='2f%%'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pit(pie(t3,labels=i,autopct='2f%%'))
#
# NameError: name 'pie' is not defined

# %%
pit.pie(t3,labels=c,autopct='2f%%',explode=[0.9,0,0,0,0],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2147e0380d0>,
# ...
#  [Text(0.7356529636047249, 1.8597888904764392, 'SUV'),
#   Text(-1.089806661655672, -0.14940361511998146, 'Sedan'),
#   Text(0.3242307715203902, -1.051130061790306, 'Hatchback'),
#   Text(1.044883587974835, -0.3438288637983082, 'Coupe'),
#   Text(1.0940353698476144, -0.11439671989350769, 'MUV')],
#  [Text(0.5517397227035437, 1.3948416678573294, '2f%'),
#   Text(-0.5944399972667301, -0.08149288097453533, '2f%'),
#   Text(0.17685314810203098, -0.5733436700674396, '2f%'),
#   Text(0.5699365025317281, -0.18754301661725897, '2f%'),
#   Text(0.596746565371426, -0.062398210851004186, '2f%')])

# %%
pit.pie(t3,labels=l,autopct='% .2f%%',explode=[0.9,0,0,0,0],shadow=True);

# %% [markdown]
# # task 4

# %%
t4=data[data['Make'].isin(['Hyundai','Mahindra','Renault'])]
t4

# %%
d=t4.index

# %%
pit.pie(t4,labels=d,autopct='2f%%')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 pit.pie(t4,labels=d,autopct='2f%%')
#
# File ~\anaconda3\New folder\lib\site-packages\matplotlib\pyplot.py:2772, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    2765 @_copy_docstring_and_deprecators(Axes.pie)
#    2766 def pie(
#    2767         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2770         textprops=None, center=(0, 0), frame=False,
#    2771         rotatelabels=False, *, normalize=True, hatch=None, data=None):
# -> 2772     return gca().pie(
#    2773         x, explode=explode, labels=labels, colors=colors,
#    2774         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
# ...

# %%
# compare the milage of these cars 'Hyundai','Mahindra','Renault','Skoda'and other features also
t4=data[data['Make'].isin(['Hyundai','Mahindra','Renault','Skoda'])]
t4['Make']
# Out:
# 12       Renault
# 13       Renault
# 14       Renault
# 15       Renault
# 16       Renault
#           ...
# 1249       Skoda
# 1250       Skoda
# 1255    Mahindra
# 1256    Mahindra
# 1257    Mahindra
# Name: Make, Length: 328, dtype: object

# %%
r=data.pivot_table(index=t4['Make'],values=['Highway_Mileage_km_litre','City_Mileage_km_litre'],aggfunc=('mean','median'))
w=r.reset_index()
w
# Out:
#        Make City_Mileage_km_litre        Highway_Mileage_km_litre
#                              mean median                     mean median
# 0   Hyundai             16.679853  16.38                18.294146  18.50
# 1  Mahindra             20.003763  16.00                18.140175  17.21
# 2   Renault             20.554286  21.04                17.690000  19.60

# %%
t=data.pivot_table(index=t4['Make'],values=['Highway_Mileage_km_litre','City_Mileage_km_litre'],aggfunc=(['mean','median']))
t
# Out:
#                           mean                                         median  \
#          City_Mileage_km_litre Highway_Mileage_km_litre City_Mileage_km_litre
# Make
# Hyundai              16.679853                18.294146                 16.38
# Mahindra             20.003763                18.140175                 16.00
# Renault              20.554286                17.690000                 21.04
#
#
#          Highway_Mileage_km_litre
# Make
# Hyundai                     18.50
# Mahindra                    17.21
# Renault                     19.60

# %%
t.plot(x='Make',kind='bar',stacked=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Make'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
w.plot(x='Make',kind='bar',stacked=False,)
pit.title('city and highway  milage')
pit.ylabel('mileage')
pit.show()

# %% [markdown]
# # task 5

# %%
# compare the milage of these cars 'Toyota','Mahindra','Volkswagen','Hyundai'and other features also
t5=data[data['Make'].isin(['Toyota','Mahindra','Volkswagen','Hyundai'])]
t5['Make']
# Out:
# 46       Hyundai
# 47       Hyundai
# 48       Hyundai
# 49       Hyundai
# 50       Hyundai
#           ...
# 1237      Toyota
# 1238      Toyota
# 1255    Mahindra
# 1256    Mahindra
# 1257    Mahindra
# Name: Make, Length: 365, dtype: object

# %%
l=data[data['Make'].isin(['Toyota','Mahindra'])]
l
# Out:
#       isker      Make       Model       Variant  Displacement  Cylinders  \
# 87       87    Toyota  Etios Liva             G        1197.0        4.0
# 88       88    Toyota  Etios Liva             V        1197.0        4.0
# 89       89    Toyota  Etios Liva            Gd        1364.0        4.0
# 90       90    Toyota  Etios Liva            Vx        1197.0        4.0
# 91       91    Toyota  Etios Liva           Vxd        1364.0        4.0
# ...     ...       ...         ...           ...           ...        ...
# 1237   1237    Toyota       Yaris     G (O) Cvt        1496.0        4.0
# 1238   1238    Toyota       Yaris     V (O) Cvt        1498.0        4.0
# 1255   1255  Mahindra      Verito        1.5 D2        1461.0        4.0
# 1256   1256  Mahindra      Verito  1.5 D4 Bs-Iv        1461.0        4.0
# 1257   1257  Mahindra      Verito  1.5 D6 Bs-Iv        1461.0        4.0
#
#       Valves_Per_Cylinder               Drivetrain Cylinder_Configuration  \
# ...

# %%
t=data.pivot_table(index=t5['Make'],values=['Highway_Mileage_km_litre','City_Mileage_km_litre'],aggfunc=('mean','median'))
h=t.reset_index()
h
# Out:
#          Make City_Mileage_km_litre        Highway_Mileage_km_litre
#                                mean median                     mean  median
# 0     Hyundai             16.679853  16.38                18.294146  18.500
# 1    Mahindra             20.003763  16.00                18.140175  17.210
# 2      Toyota             14.293065  13.60                18.448750  17.935
# 3  Volkswagen             16.225000  15.30                19.229333  20.000

# %%
h.plot(x='Make',kind='bar',stacked=False,)
pit.title('city and highway  milage')
pit.ylabel('mileage')
pit.show()

# %% [markdown]
# # task 6

# %%
#better spread of fuel economy and model types
data['avg_mileage']=data[['Highway_Mileage_km_litre','City_Mileage_km_litre']].mean(axis=1)
data['avg_mileage']
# Out:
# 0       23.600
# 1       23.600
# 2          NaN
# 3       23.600
# 4       23.600
#          ...
# 1271    23.850
# 1272    23.850
# 1273    18.000
# 1274    15.350
# 1275     9.905
# Name: avg_mileage, Length: 1276, dtype: float64

# %%
t6=data.groupby('Make')['avg_mileage'].mean()
t6
# Out:
# Make
# Aston Martin         7.833333
# Audi                12.496875
# Bajaj                     NaN
# Bentley              6.430000
# Bmw                 14.731250
# Bugatti                   NaN
# Datsun              21.528889
# Dc                   9.000000
# Ferrari              5.610000
# Fiat                17.229545
# Force               15.500000
# Ford                11.945000
# Honda               17.625714
# Hyundai             17.288571
# Icml                 9.860000
# Isuzu               10.800000
# Jaguar              11.885455
# Jeep                12.837500
# Kia                       NaN
# Lamborghini          5.858333
# Land Rover                NaN
# Land Rover Rover    10.649500
# Lexus               18.150000
# Mahindra            20.918495
# Maruti Suzuki       21.518696
# Maruti Suzuki R           NaN
# Maserati             5.433333
# Mg                        NaN
# Mini                11.675000
# Mitsubishi           8.734167
# Nissan              15.924688
# ...

# %%
a=t6.sort_values(ascending=False)
a
# Out:
# Make
# Datsun              21.528889
# Maruti Suzuki       21.518696
# Renault             21.143750
# Mahindra            20.918495
# Tata                20.080536
# Lexus               18.150000
# Honda               17.625714
# Volkswagen          17.504375
# Hyundai             17.288571
# Fiat                17.229545
# Nissan              15.924688
# Skoda               15.672500
# Force               15.500000
# Premier             15.475000
# Toyota              15.171613
# Bmw                 14.731250
# Volvo               13.851154
# Jeep                12.837500
# Audi                12.496875
# Ford                11.945000
# Jaguar              11.885455
# Mini                11.675000
# Isuzu               10.800000
# Land Rover Rover    10.649500
# Icml                 9.860000
# Dc                   9.000000
# Mitsubishi           8.734167
# Porsche              8.235714
# Aston Martin         7.833333
# Bentley              6.430000
# Lamborghini          5.858333
# ...

# %%
b=a.index
b
# Out:
# Index(['Datsun', 'Maruti Suzuki', 'Renault', 'Mahindra', 'Tata', 'Lexus',
#        'Honda', 'Volkswagen', 'Hyundai', 'Fiat', 'Nissan', 'Skoda', 'Force',
#        'Premier', 'Toyota', 'Bmw', 'Volvo', 'Jeep', 'Audi', 'Ford', 'Jaguar',
#        'Mini', 'Isuzu', 'Land Rover Rover', 'Icml', 'Dc', 'Mitsubishi',
#        'Porsche', 'Aston Martin', 'Bentley', 'Lamborghini', 'Ferrari',
#        'Maserati', 'Bajaj', 'Bugatti', 'Kia', 'Land Rover', 'Maruti Suzuki R',
#        'Mg'],
#       dtype='object', name='Make')

# %%
c=a.values
c
# Out:
# array([21.52888889, 21.51869565, 21.14375   , 20.91849462, 20.08053571,
#        18.15      , 17.62571429, 17.504375  , 17.28857143, 17.22954545,
#        15.9246875 , 15.6725    , 15.5       , 15.475     , 15.1716129 ,
#        14.73125   , 13.85115385, 12.8375    , 12.496875  , 11.945     ,
#        11.88545455, 11.675     , 10.8       , 10.6495    ,  9.86      ,
#         9.        ,  8.73416667,  8.23571429,  7.83333333,  6.43      ,
#         5.85833333,  5.61      ,  5.43333333,         nan,         nan,
#                nan,         nan,         nan,         nan])

# %%
pit.barh(b,c,label='avg mileage',color='k')
pit.title('company wise milage')
pit.xlabel('milage')
pit.ylabel('manafacture_name')
pit.legend()
pit.show()

# %% [markdown]
# # task 7

# %%
#top 10 displacement treand
t7=data.groupby(['Displacement'])['Fuel_Tank_Capacity_litre'].mean().sort_values(ascending=False).head(10)
t7
# Out:
# Displacement
# 4367.0    105.000000
# 6749.0    100.000000
# 2925.0     96.500000
# 6417.0     93.500000
# 3604.0     93.500000
# 5700.0     93.000000
# 4461.0     93.000000
# 3855.0     92.000000
# 6496.0     92.000000
# 4999.0     91.666667
# Name: Fuel_Tank_Capacity_litre, dtype: float64

# %%
b=data.groupby(['Make'])[['Displacement']]
b

# %%
x=data.groupby(['Make'])[['Displacement','Fuel_Tank_Capacity_litre']].mean().sort_values(by='Displacement',ascending=False).head(10)
x
# Out:
#                   Displacement  Fuel_Tank_Capacity_litre
# Make
# Bugatti            7993.000000                       NaN
# Bentley            5447.833333                 88.333333
# Lamborghini        5409.692308                 88.750000
# Aston Martin       5038.333333                 81.166667
# Ferrari            4589.500000                 86.750000
# Lexus              3491.600000                 76.777778
# Maserati           3363.888889                 75.666667
# Land Rover Rover   3199.703704                 90.000000
# Porsche            3062.928571                 74.357143
# Land Rover         2795.000000                 83.600000

# %%
i=t7.index
i
# Out:
# Float64Index([4367.0, 6749.0, 2925.0, 6417.0, 3604.0, 5700.0, 4461.0, 3855.0,
#               6496.0, 4999.0],
#              dtype='float64', name='Displacement')

# %%
h=t7.values
h
# Out:
# array([105.        , 100.        ,  96.5       ,  93.5       ,
#         93.5       ,  93.        ,  93.        ,  92.        ,
#         92.        ,  91.66666667])

# %%
pit.scatter(i,h,label='mileage')
pit.xlabel('brand')
pit.ylabel('milage')
pit.legend()
pit.show()

# %% [markdown]
# # task 8

# %%
#fuel tank capicity and there trend  line using sccaterr with top 10full tank capicity
t8=data.groupby('Fuel_Tank_Capacity_litre')['avg_mileage'].mean().sort_values(ascending=False).head(10)
t8
# Out:
# Fuel_Tank_Capacity_litre
# 28.0    24.550000
# 24.0    23.600000
# 48.0    22.611538
# 37.0    22.165641
# 35.0    20.802434
# 43.0    20.680333
# 32.0    19.999286
# 44.0    18.839000
# 51.0    18.432500
# 45.0    18.044444
# Name: avg_mileage, dtype: float64

# %%
t=t8.index
t
# Out:
# Float64Index([28.0, 24.0, 48.0, 37.0, 35.0, 43.0, 32.0, 44.0, 51.0, 45.0], dtype='float64', name='Fuel_Tank_Capacity_litre')

# %%
a=t8.values
a
# Out:
# array([24.55      , 23.6       , 22.61153846, 22.16564103, 20.80243421,
#        20.68033333, 19.99928571, 18.839     , 18.4325    , 18.04444444])

# %%
d=data['Fuel_Tank_Capacity_litre'].corr(data['avg_mileage']).round(1)
pit.scatter(t,a,label='r='+str(d))
pit.title('scatter plot')
pit.xlabel('fuel tank capicity')
pit.ylabel('milage')
pit.legend()
pit.show()

# %% [markdown]
# # task 9

# %%
#top 10 safe care by using bar graph
t9=data[(data['Central_Locking']=='Yes')&(data['Child_Safety_Locks']=='Yes')  &(data['Hill_Assist']=='Yes')&(data['High_Speed_Alert_System']=='Yes')]
t9=t9.sort_values(by='avg_mileage',ascending=False).head(10)
k=t9['avg_mileage'].values
k
# Out:
# array([18.8 , 17.8 , 17.8 , 17.  , 17.  , 14.98, 14.98, 14.98, 13.85,
#        13.85])

# %%
l=t9['Make'].values
l
# Out:
# array(['Lexus', 'Renault', 'Renault', 'Volkswagen', 'Volkswagen', 'Bmw',
#        'Bmw', 'Bmw', 'Hyundai', 'Hyundai'], dtype=object)

# %%
pit.bar(k,l,label='mileage')
pit.xlabel('brand')
pit.ylabel('milage')
pit.legend()
pit.show()

# %% [markdown]
# # task 10

# %%
#filter the data on the base of Normal, Comfort, Eco, Sport, Power Mode
data[data['Drive_Modes']=='Normal, Comfort, Eco, Sport, Power Mode']
# Out:
#      isker  Make Model                    Variant  Displacement  Cylinders  \
# 321    321  Audi    Q8  55 Tfsi Quattro Tiptronic        2995.0        4.0
# 330    330  Audi  A8 L            55 Tfsi Quattro        2995.0        8.0
#
#      Valves_Per_Cylinder             Drivetrain Cylinder_Configuration  \
# 321                  4.0  AWD (All Wheel Drive)                      V
# 330                  4.0  AWD (All Wheel Drive)                      V
#
#          Engine_Location  ... Automatic_Headlamps  \
# 321  Front, Longitudinal  ...                 NaN
# 330  Front, Longitudinal  ...                 NaN
#
#                                            Engine_Type ASR_/_Traction_Control  \
# 321  Roller cam follower, continuous intake and exh...                    Yes
# 330                                                NaN                    Yes
#
#      Cruise_Control  USB_Ports  Heads-Up_Display Welcome_Lights  Battery  \
# ...

# %%
data['average_milage']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#          ...
# 1271    23.850
# 1272    23.850
# 1273    18.000
# 1274    15.350
# 1275     9.905
# Name: average_milage, Length: 1276, dtype: float64

# %% [markdown]
# # task 11

# %%
# average mileage of hyundai,maruti suzuki,tata,bmw
t11=data[data['Make'].isin(['Hyundai','Maruti Suzuki','Tata','Bmw'])]
t11=t11.loc[:,['Make','Model','Highway_Mileage_km_litre','City_Mileage_km_litre']]

# %%
data['average_milage']=(data['City_Mileage_km_litre']+data['Highway_Mileage_km_litre'])/2

# %%
#hyundai
x=data[data['Make']=='Hyundai'][['Make','average_milage']].dropna()
pit.hist(x=x['average_milage'])
# Out:
# (array([ 8.,  0., 14.,  1.,  2.,  5.,  5.,  2.,  0.,  2.]),
#  array([13.125 , 14.2125, 15.3   , 16.3875, 17.475 , 18.5625, 19.65  ,
#         20.7375, 21.825 , 22.9125, 24.    ]),
#  <BarContainer object of 10 artists>)

# %%
#maruti suzuki
y=data[data['Make']=='Maruti Suzuki'][['Make','average_milage']].dropna()
pit.hist(x=z['average_milage'])
# Out:
# (array([ 3.,  0.,  4.,  7.,  0.,  0.,  2.,  4.,  0., 13.]),
#  array([11.9  , 13.102, 14.304, 15.506, 16.708, 17.91 , 19.112, 20.314,
#         21.516, 22.718, 23.92 ]),
#  <BarContainer object of 10 artists>)

# %%
#tata
z=data[data['Make']=='Tata'][['Make','average_milage']].dropna()
pit.hist(x=z['average_milage'])
# Out:
# (array([ 3.,  0.,  4.,  7.,  0.,  0.,  2.,  4.,  0., 13.]),
#  array([11.9  , 13.102, 14.304, 15.506, 16.708, 17.91 , 19.112, 20.314,
#         21.516, 22.718, 23.92 ]),
#  <BarContainer object of 10 artists>)

# %%
#bmw
w=data[data['Make']=='Bmw'][['Make','average_milage']].dropna()
pit.hist(x=w['average_milage'])
# Out:
# (array([1., 0., 2., 1., 0., 0., 4., 0., 3., 3.]),
#  array([ 6.195 ,  7.5095,  8.824 , 10.1385, 11.453 , 12.7675, 14.082 ,
#         15.3965, 16.711 , 18.0255, 19.34  ]),
#  <BarContainer object of 10 artists>)
