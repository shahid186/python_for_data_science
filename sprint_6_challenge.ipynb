# %%
import matplotlib.pyplot as pit
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('DS1_C4_S6_House_Prices_Data_Challenge.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data=pd.read_csv('DS1_C4_S6_House_Prices_Data_Challenge.csv')
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # task 1

# %%
#peoples preffer house with 6000 square feet and corner house
t1=data[(data['LotArea']>=6000) & (data['LotConfig']=='Corner')]
t1
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 14      15          20       RL          NaN    10920   Pave   NaN      IR1
# 15      16          45       RM         51.0     6120   Pave   NaN      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1407  1408          20       RL          NaN     8780   Pave   NaN      IR1
# 1413  1414          20       RL         88.0    10994   Pave   NaN      IR1
# 1420  1421          60       RL         90.0    11700   Pave   NaN      Reg
# 1428  1429          30       RM         60.0     7200   Pave   NaN      Reg
# 1429  1430          20       RL          NaN    12546   Pave   NaN      IR1
#
# ...

# %% [markdown]
# # task 2

# %%
#one family and one story preffer there house on flat
t2=data[(data['HouseStyle']=='1Story') & (data['BldgType']=='1Fam') & (data['LandContour']=='Lvl')]
t2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# 12      13          20       RL          NaN    12968   Pave   NaN      IR2
# 13      14          20       RL         91.0    10652   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# # task 3

# %%
#compare town house are hot selling properties in california
t3=data[(data['BldgType']=='TwnhsE')| (data['BldgType']=='TwnhsE')]
t3.groupby('HouseStyle')['Id'].count().to_frame()
# Out:
#             Id
# HouseStyle
# 1Story      78
# 2Story      30
# SFoyer       4
# SLvl         2

# %% [markdown]
# # task 4

# %%
#house with three bedrooms a basement and exterior are popular among customers
t4=data[(data['BedroomAbvGr']>=3) & (data['ExterQual']!='NA') & (data['Exterior1st']=='CemntBd') | (data['Exterior2nd']=='CemntBd')]
t4
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 23      24         120       RM         44.0     4224   Pave   NaN      Reg
# 108    109          50       RM         85.0     8500   Pave   NaN      Reg
# 196    197          20       RL         79.0     9416   Pave   NaN      Reg
# 261    262          60       RL         69.0     9588   Pave   NaN      IR1
# 278    279          20       RL        107.0    14450   Pave   NaN      Reg
# 304    305          75       RM         87.0    18386   Pave   NaN      Reg
# 305    306          20       RL         80.0    10386   Pave   NaN      Reg
# 316    317          60       RL         94.0    13005   Pave   NaN      IR1
# 344    345         160       RM         36.0     2592   Pave   NaN      Reg
# 349    350          60       RL         56.0    20431   Pave   NaN      IR2
# 357    358         120       RM         44.0     4224   Pave   NaN      Reg
# ...

# %% [markdown]
# # task5

# %%
#most families own two cars and prefer a garage with atleast 500 square feet
t5= data[(data['GarageArea']>=500) &(data['GarageCars']==2)][['GarageArea','GarageCars']]
t5
# Out:
#       GarageArea  GarageCars
# 0            548           2
# 2            608           2
# 6            636           2
# 15           576           2
# 17           516           2
# ...          ...         ...
# 1440         672           2
# 1444         626           2
# 1447         556           2
# 1452         525           2
# 1456         500           2
#
# [439 rows x 2 columns]

# %%
pip install mysql-connector-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector as sql
import pandas as pd

# %%
conn=sql.connect(host='localhost',database='shahid',user='root',password='shahid786')

# %%
if conn.is_connected():
    print('connected successfully')
# Out:
# connected successfully

# %%
s=conn.cursor()

# %%
from sqlalchemy import create_engine

# %%
e=create_engine("mysql+pymysql://root:shahid786@localhost/shahid")

# %%
t1.to_sql('t1',e,index=False)
# Out:
# 241

# %%
t2.to_sql('t2',e,index=False)
# Out:
# 545

# %%
t3.to_sql('t3',e,index=False)
# Out:
# 114

# %%
t4.to_sql('t4',e,index=False)
# Out:
# 44

# %%
t5.to_sql('t5',e,index=False)
# Out:
# 439
