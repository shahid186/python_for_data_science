# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('DS1_C4_S3_Loan_Data_Practice.csv.csv')

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # task 1

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
m=data[(data['Gender']=='Male')]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
n=data[(data['Gender']=='Male')]

# %%
n=data[(data['Gender']=='Male')]

# %%
n=data[(data['Gender']=='Married')]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
n=data[(data['Gender']=='Male')]

# %%
b=data[(data['Gender']=='Male')]

# %%
v=data[(data['Gender']=='Male')&(data['Education']=='Graduate')][['Gender']]
v.head(5)
# Out:
#   Gender
# 0   Male
# 1   Male
# 2   Male
# 4   Male
# 5   Male

# %%
m=data[(data['Gender']=='Male') & (data['Education']=='Graduate')][['Married','Gender']]
m.head(10)
# Out:
#    Married Gender
# 0       No   Male
# 1      Yes   Male
# 2      Yes   Male
# 4       No   Male
# 5      Yes   Male
# 7      Yes   Male
# 8      Yes   Male
# 9      Yes   Male
# 10     Yes   Male
# 11     Yes   Male

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
b=data[(data['Gender']=='Male')&(data['Education']=='Graduate')]
b.head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 1             4583             1508.0         128               360
# 2             3000                0.0          66               360
# 4             6000                0.0         141               360
# 5             5417             4196.0         267               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 1               1         Rural           N
# 2               1         Urban           Y
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
d=data[(data['Gender']=='Male')&(data['Education']=='Graduate')][['Married']]
d
# Out:
#     Married
# 0        No
# 1       Yes
# 2       Yes
# 4        No
# 5       Yes
# ..      ...
# 606     Yes
# 608     Yes
# 610     Yes
# 611     Yes
# 612     Yes
#
# [388 rows x 1 columns]

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['Loan_Amount_Term'].replace(to_replace=[89],value=90,inplace=True)

# %%
data['Loan_Amount_Term'].replace(to_replace=[90],value=90,inplace=True)

# %%
data['Loan_Amount_Term'].replace(to_replace=[89],value=90,inplace=True)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['Loan_Amount_Term'].replace(to_replace=[89],value=90,inplace=True)

# %%
data['Loan_Amount_Term'].replace(to_replace=[12],value=60,inplace =True)

# %%
import sympy as s

# %%
data['Loan_Amount_Term'].replace(to_replace=[12],value=60,inplace=True)
data

# %%
data['Education'].replace(to_replace=['Graduate'],value='shahid is good',inplace=True)
data.head(10)
# Out:
#     Loan_ID Gender Married Dependents       Education Self_Employed  \
# 0  LP001002   Male      No          0  shahid is good            No
# 1  LP001003   Male     Yes          1  shahid is good            No
# 2  LP001005   Male     Yes          0  shahid is good           Yes
# 3  LP001006   Male     Yes          0    Not Graduate            No
# 4  LP001008   Male      No          0  shahid is good            No
# 5  LP001011   Male     Yes          2  shahid is good           Yes
# 6  LP001013   Male     Yes          0    Not Graduate            No
# 7  LP001014   Male     Yes         3+  shahid is good            No
# 8  LP001018   Male     Yes          2  shahid is good            No
# 9  LP001020   Male     Yes          1  shahid is good            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 1             4583             1508.0         128               360
# ...

# %%
data['Education'].replace(to_replace=['Graduate'],value='not graduated',inplace=True)

# %%
data
# Out:
#       Loan_ID  Gender Married Dependents      Education Self_Employed  \
# 0    LP001002    Male      No          0  not graduated            No
# 1    LP001003    Male     Yes          1  not graduated            No
# 2    LP001005    Male     Yes          0  not graduated           Yes
# 3    LP001006    Male     Yes          0   Not Graduate            No
# 4    LP001008    Male      No          0  not graduated            No
# ..        ...     ...     ...        ...            ...           ...
# 609  LP002978  Female      No          0  not graduated            No
# 610  LP002979    Male     Yes         3+  not graduated            No
# 611  LP002983    Male     Yes          1  not graduated            No
# 612  LP002984    Male     Yes          2  not graduated            No
# 613  LP002990  Female      No          0  not graduated           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data.insert(data,)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
b=data[(data['Gender']=='Male')&(data['Education']=='Graduate')]
b
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 1    LP001003   Male     Yes          1  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
j=data[(data['Gender']=='Male')&(data['Education']=='Graduate')]
j
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 1    LP001003   Male     Yes          1  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
b=data[(data['Gender']=='Male')&(data['Education']=='Graduate') &(data['Loan_Status']=='Y')][['Self_Employed']]

# %%
G=data[(data['Gender']=='Male') & (data['Education']=='Graduate') & (data['Loan_Status']=='Y')]
G.head()
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
# 4  LP001008   Male      No          0  Graduate            No
# 5  LP001011   Male     Yes          2  Graduate           Yes
# 8  LP001018   Male     Yes          2  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         146               360
# 2             3000                0.0          66               360
# 4             6000                0.0         141               360
# 5             5417             4196.0         267               360
# 8             4006             1526.0         168               360
#
#    Credit_History Property_Area Loan_Status
# 0               1         Urban           Y
# 2               1         Urban           Y
# 4               1         Urban           Y
# ...

# %%
data[(data['Gender']=='Male')]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes         3+      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#no of males whoeseducation is graduation andthere lone got approved
s=data[(data['Gender']=='Male') & (data['Education']=='Graduate') & (data['Loan_Status']=='Y')]
s
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 0    LP001002   Male      No          0  Graduate            No
# 2    LP001005   Male     Yes          0  Graduate           Yes
# 4    LP001008   Male      No          0  Graduate            No
# 5    LP001011   Male     Yes          2  Graduate           Yes
# 8    LP001018   Male     Yes          2  Graduate            No
# ..        ...    ...     ...        ...       ...           ...
# 606  LP002961   Male     Yes          1  Graduate            No
# 608  LP002974   Male     Yes          0  Graduate            No
# 610  LP002979   Male     Yes         3+  Graduate            No
# 611  LP002983   Male     Yes          1  Graduate            No
# 612  LP002984   Male     Yes          2  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0         146               360
# ...

# %%
s['Gender'].shape[0]
# Out:
# 279

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# # task 2

# %%
#female customer who are self employeed and having income more than 4000
g=data[(data['Gender']=='Female') & (data['Self_Employed']=='Yes') & (data['ApplicantIncome']>=4000)]
g
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 113  LP001392  Female      No          1      Graduate           Yes
# 353  LP002142  Female     Yes          0      Graduate           Yes
# 370  LP002194  Female      No          0      Graduate           Yes
# 404  LP002301  Female      No          0      Graduate           Yes
# 430  LP002377  Female      No          1      Graduate           Yes
# 439  LP002407  Female     Yes          0  Not Graduate           Yes
# 463  LP002489  Female      No          1  Not Graduate           Yes
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 613  LP002990  Female      No          0      Graduate           Yes
#
# ...

# %%
g.shape[0]
# Out:
# 12

# %% [markdown]
# # task 3

# %%
#history of lone approval of customers they have more than three dependents  have rural property area
t=data[(data['Dependents']=='3+') & (data['Property_Area']=='Rural') & (data['Loan_Status']=='Y')]
t
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 126  LP001448    Male     Yes         3+      Graduate            No
# 213  LP001715    Male     Yes         3+  Not Graduate           Yes
# 255  LP001846  Female      No         3+      Graduate            No
# 324  LP002065    Male     Yes         3+      Graduate            No
# 352  LP002141    Male     Yes         3+      Graduate            No
# 376  LP002219    Male     Yes         3+      Graduate            No
# 390  LP002255    Male      No         3+      Graduate            No
# 391  LP002262    Male     Yes         3+      Graduate            No
# 481  LP002536    Male     Yes         3+  Not Graduate            No
# 515  LP002659    Male     Yes         3+      Graduate            No
# 522  LP002692    Male     Yes         3+      Graduate           Yes
# 539  LP002740    Male     Yes         3+      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
#
# ...

# %% [markdown]
# # task 4

# %%
#avg income of previous customers for whom a lone worth 290 was approved 
d=data[(data['LoanAmount']>=290)]['ApplicantIncome'].mean()
round(d,0)
# Out:
# 17737.0

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
d=data[(data['LoanAmount']>=290)]['ApplicantIncome'].mean()

# %%
h['Gender']=data.replace(value)

# %%
h=data[(data['Gender']=='Male')][['Married','Education']]
h.rename(columns={'Married':'shahid'},inplace=True)

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.rename(columns={'Gender':'shahid'},inplace=True)

# %%
data.rename(columns={'shahid':'babay'},inplace=True)

# %%
h.rename(columns={'Education':'irtiza'},inplace=True)
h
# Out:
#     shahid        irtiza
# 0       No      Graduate
# 1      Yes      Graduate
# 2      Yes      Graduate
# 3      Yes  Not Graduate
# 4       No      Graduate
# ..     ...           ...
# 607    Yes  Not Graduate
# 608    Yes      Graduate
# 610    Yes      Graduate
# 611    Yes      Graduate
# 612    Yes      Graduate
#
# [502 rows x 2 columns]

# %%
h=data[(data['Gender']=='Male')][['Married','Education']]
h.rename(columns={'Married':'shahid'},inplace=True)
h
# Out:
#     shahid     Education
# 0       No      Graduate
# 1      Yes      Graduate
# 2      Yes      Graduate
# 3      Yes  Not Graduate
# 4       No      Graduate
# ..     ...           ...
# 607    Yes  Not Graduate
# 608    Yes      Graduate
# 610    Yes      Graduate
# 611    Yes      Graduate
# 612    Yes      Graduate
#
# [502 rows x 2 columns]

# %%
c=data[(data['LoanAmount']>290)]['ApplicantIncome'].mean()
c
# Out:
# 18166.15625

# %%
m=data[(data['LoanAmount']>=290)]['ApplicantIncome'].mean()

# %%
x=data[(data['LoanAmount']>=290)]['ApplicantIncome'].mean()
# Out:
# 17736.878787878788

# %%
b=data[(data['LoanAmount']>290)]['ApplicantIncome'].mean()
b
# Out:
# 18166.15625

# %%
data[(data['LoanAmount']>290)]['ApplicantIncome'].mean()
# Out:
# 18166.15625

# %% [markdown]
# # task 5

# %%
#find the male and female who are unmarried and self employed
m=data[(data['Married']=='No') & (data['Self_Employed']=='No')]
m
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 15   LP001032    Male      No          0      Graduate            No
# 16   LP001034    Male      No          1  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 588  LP002925    Male      No          0      Graduate            No
# 595  LP002940    Male      No          0  Not Graduate            No
# 597  LP002943    Male      No          1      Graduate            No
# 603  LP002958    Male      No          0      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
data['Gender'].value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
data['babay'].value_counts()
# Out:
# Male      502
# Female    112
# Name: babay, dtype: int64

# %%
data.columns
# Out:
# Index(['Loan_ID', 'babay', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['babay'].value_counts()
# Out:
# Male      502
# Female    112
# Name: babay, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data['Married'].value_counts()
# Out:
# Yes    401
# No     213
# Name: Married, dtype: int64

# %%
data['Gender'].value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %% [markdown]
# # task 6

# %%
g=data[(data['Property_Area'].isin('Urban'))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 g=data[(data['Property_Area']).isin('Urban')]
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\series.py:5563, in Series.isin(self, values)
#    5490 def isin(self, values) -> Series:
#    5491     """
#    5492     Whether elements in Series are contained in `values`.
#    5493
#    (...)
#    5561     dtype: bool
#    5562     """
# -> 5563     result = algorithms.isin(self._values, values)
#    5564     return self._constructor(result, index=self.index).__finalize__(
#    5565         self, method="isin"
#    5566     )
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\algorithms.py:459, in isin(comps, values)
#     454     raise TypeError(
#     455         "only list-like objects are allowed to be passed "
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
v=data[(data['Property_Area']=='Urban')][['Property_Area']]
v
# Out:
#     Property_Area
# 0           Urban
# 2           Urban
# 3           Urban
# 4           Urban
# 5           Urban
# ..            ...
# 600         Urban
# 602         Urban
# 605         Urban
# 611         Urban
# 612         Urban
#
# [202 rows x 1 columns]

# %%
c=data[(data['Property_Area']=='Urban')][['Property_Area','ApplicantIncome']]
c
# Out:
#     Property_Area  ApplicantIncome
# 0           Urban             5849
# 2           Urban             3000
# 3           Urban             2583
# 4           Urban             6000
# 5           Urban             5417
# ..            ...              ...
# 600         Urban              416
# 602         Urban             5703
# 605         Urban             2400
# 611         Urban             8072
# 612         Urban             7583
#
# [202 rows x 2 columns]

# %%
data[data['Gender'].isin('Male')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Gender'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#bank  wise to find out applicants income by area
x=data[(data['Property_Area']=='Urban')][['Property_Area','ApplicantIncome']]
x
# Out:
#     Property_Area  ApplicantIncome
# 0           Urban             5849
# 2           Urban             3000
# 3           Urban             2583
# 4           Urban             6000
# 5           Urban             5417
# ..            ...              ...
# 600         Urban              416
# 602         Urban             5703
# 605         Urban             2400
# 611         Urban             8072
# 612         Urban             7583
#
# [202 rows x 2 columns]

# %%
x=data[(data['Property_Area']=='Rural')][['Property_Area','ApplicantIncome']]
x
# Out:
#     Property_Area  ApplicantIncome
# 1           Rural             4583
# 13          Rural             1853
# 18          Rural             4887
# 23          Rural             3365
# 32          Rural             4692
# ..            ...              ...
# 603         Rural             3676
# 607         Rural             3987
# 608         Rural             3232
# 609         Rural             2900
# 610         Rural             4106
#
# [179 rows x 2 columns]

# %%
x=data[(data['Property_Area']=='Semiurban')][['Property_Area','ApplicantIncome']]
x
# Out:
#     Property_Area  ApplicantIncome
# 7       Semiurban             3036
# 9       Semiurban            12841
# 22      Semiurban             2600
# 24      Semiurban             3717
# 25      Semiurban             9560
# ..            ...              ...
# 592     Semiurban             9357
# 597     Semiurban             2987
# 604     Semiurban            12000
# 606     Semiurban             3400
# 613     Semiurban             4583
#
# [233 rows x 2 columns]

# %% [markdown]
# # task 7

# %%
#determine the no of customers whoes co applicants have gotten there loan approved
j=data[data['Married']=='Yes'][['CoapplicantIncome']].mean()
j
# Out:
# CoapplicantIncome    1783.087082
# dtype: float64

# %%
t1=data[data['Loan_Status']=='Y'][['CoapplicantIncome']].mean()
t1
# Out:
# CoapplicantIncome    1504.516398
# dtype: float64

# %%
s1=data[(data['Married']=='Yes') &(data['CoapplicantIncome']<1504.516398)]
s1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 10   LP001024    Male     Yes          2      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# 18   LP001038    Male     Yes          0  Not Graduate            No
# 20   LP001043    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 604  LP002959  Female     Yes          1      Graduate            No
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
s1.shape[0]
# Out:
# 191

# %%
data.shape
# Out:
# (614, 13)

# %% [markdown]
# # task 8

# %%
#no of customers whoes income range is in b/w 10256 and 150000
b=data[(data['Education']=='Graduate') & (data['ApplicantIncome'].between(10256,150000))]
b
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 34   LP001100    Male      No         3+  Graduate            No
# 54   LP001186  Female     Yes          1  Graduate           Yes
# 67   LP001233    Male     Yes          1  Graduate            No
# 102  LP001350    Male     Yes          1  Graduate            No
# 106  LP001369    Male     Yes          2  Graduate            No
# 115  LP001401    Male     Yes          1  Graduate            No
# 119  LP001422  Female      No          0  Graduate            No
# 126  LP001448    Male     Yes         3+  Graduate            No
# 128  LP001451    Male     Yes          1  Graduate           Yes
# 130  LP001469    Male      No          0  Graduate           Yes
# 138  LP001492    Male      No          0  Graduate            No
# 144  LP001508    Male     Yes          2  Graduate            No
# ...

# %%
b.shape[0]
# Out:
# 48
